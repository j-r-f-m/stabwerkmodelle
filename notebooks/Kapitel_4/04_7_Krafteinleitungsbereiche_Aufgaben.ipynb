# %% [markdown]
# # Kapitel 4.7 - Krafteinleitungsbereiche - Beispiel 1
# s. 126

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Input / Gegeben - 4.7.1 - S.126
a_lager = 20 # cm
b_lager = 20 # cm
t_lager = 1.2 # cm

fck = 30 # N/mm^2

F_ed = 1000 # kN
M_ed = 1000 # kNm
e = 5 # cm

# %%
# test
import sys

# get current location
#print(sys.path)
# add location of the module
sys.path.append(
    "c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\src\\stabwerkmodelle"
)
# import wanted module
import mats_beton
import teilflächenbelastung

f_cd = mats_beton.f_cd(0.85, 30, 1.5)
b1_red_berrechnet = teilflächenbelastung.b1_red(0.2, 0.05)
b2_red_berrechnet = teilflächenbelastung.b2(b1_red_berrechnet)
a_c0_berrechnet = teilflächenbelastung.A_c0(b1_red_berrechnet, b_lager/100)


# Ausgabe Zwischenrechnungen
print_fcd = f"Druckfestigkeit des Betons: f_cd = {f_cd} N/mm^2"
print_b1_red = f"Reduzierte Lasteinleitungstiefe d1_red = {b1_red_berrechnet} m"
print_b2_red = f"Lastausbreitungstiefe d2_red = {round(b2_red_berrechnet,2)} m"
print_A_c0 = f"Fläche der Lastausbreitung: A_c0 = {round(a_c0_berrechnet,2)} m^2"

print(print_fcd)
print(print_b1_red)
print(print_b2_red)
print(print_A_c0)
# Out:
# Druckfestigkeit des Betons: f_cd = 17.0 N/mm^2
# Reduzierte Lasteinleitungstiefe d1_red = 0.1 m
# Lastausbreitungstiefe d2,red = 0.3 m
# Fläche der Lastausbreitung: A_c0 = 0.02 m^2

# %%
import sys

print(sys.path)
# Out:
# ['c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\notebooks\\Kapitel_4', 'C:\\Users\\donut\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\donut\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\donut\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\donut\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\venv', '', 'c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\venv\\Lib\\site-packages', 'c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\venv\\Lib\\site-packages\\win32', 'c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\venv\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\donut\\programming\\python_projects\\stabwerkmodelle\\src\\stabwerkmodelle']
